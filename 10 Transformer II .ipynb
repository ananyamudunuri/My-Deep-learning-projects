# %% [markdown]
# # 1. Load the SQUAD 2.0

# %%
# %%capture
# !pip install transformers

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# %%capture
import json
import pandas as pd
import numpy as np
from pathlib import Path
import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import BertTokenizer, BertForQuestionAnswering
import time

# %%
is_cuda = torch.cuda.is_available()

if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# GPU is available

# %%
# %%capture
# !mkdir squad
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json -O squad/train-v2.0.json
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json -O squad/dev-v2.0.json

# %% [markdown]
# # Get the Data and store it , using only 50 samples

# %%
import json
from pathlib import Path

# Define the paths to training and validation datasets
train_path = Path('squad/train-v2.0.json')
val_path = Path('squad/dev-v2.0.json')

# Function to load SQuAD data and extract samples
def load_squad_data(path, exclude=None, num_samples=22):
    with open(path, 'r') as f:
        squad_dict = json.load(f)

    texts = []
    questions = []
    answers = []

    count = 0  # Counter to limit the number of samples
    for group in squad_dict['data']:
        for passage in group['paragraphs']:
            context = passage['context']
            for qa in passage['qas']:
                if not qa["is_impossible"]:  # Exclude unanswerable questions
                    question = qa['question']
                    answer = qa['answers'][0]  # Use the first answer

                    # Check for duplicates in the exclude set
                    if exclude and (context, question) in exclude:
                        continue

                    texts.append(context)
                    questions.append(question)
                    answers.append(answer)
                    count += 1
                    if count >= num_samples:  # Stop after reaching the desired number of samples
                        return texts, questions, answers

    return texts, questions, answers

# Load training data
train_texts, train_queries, train_answers = load_squad_data(train_path, num_samples=50)  # Load 22 training samples
train_set = set(zip(train_texts, train_queries))  # Create a set of (context, question) pairs

# Load validation data excluding training data
val_texts, val_queries, val_answers = load_squad_data(val_path, exclude=train_set, num_samples=50)

# %%
import json

# Define the path to the SQuAD 2.0 training data
path = "squad/train-v2.0.json"

# Load and preprocess the SQuAD 2.0 data into the desired structure
def load_squad_samples(path, num_samples=50):
    with open(path, 'r') as f:
        squad_dict = json.load(f)

    samples = []  # List to store the structured data
    count = 0     # Counter to limit the number of samples

    for group in squad_dict['data']:
        for passage in group['paragraphs']:
            context = passage['context']
            questions = []  # Collect questions and answers for this context
            for qa in passage['qas']:
                if not qa["is_impossible"]:  # Exclude unanswerable questions
                    questions.append({
                        "question": qa['question'],
                        "answer": qa['answers'][0]['text']  # Use the first answer
                    })
                    count += 1
                    if count >= num_samples:  # Stop after reaching the desired number of samples
                        samples.append({"context": context, "questions": questions})
                        return samples

            # Add context with all its questions if within sample limit
            if questions:
                samples.append({"context": context, "questions": questions})

    return samples

# Extract 22 samples
samples = load_squad_samples(path, num_samples=50)

# %% [markdown]
# # 2. Display a few raw QnA data samples.

# %%
# Extract 22 samples
train_texts, train_queries, train_answers = load_squad_data(path, num_samples=50)

# Display the number of extracted samples
print(f"Extracted {len(train_texts)} samples.")

# Display the first few samples for verification
for i in range(50):  # Display the samples
    print(f"Sample {i+1}:")
    print(f"Context: {train_texts[i][:150]}...")  # Truncated for readability
    print(f"Question: {train_queries[i]}")
    print(f"Answer: {train_answers[i]['text']}")
    print("-" * 80)
# Out:
# Extracted 50 samples.
# Sample 1:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: When did Beyonce start becoming popular?
# Answer: in the late 1990s
# --------------------------------------------------------------------------------
# Sample 2:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: What areas did Beyonce compete in when she was growing up?
# Answer: singing and dancing
# --------------------------------------------------------------------------------
# Sample 3:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: When did Beyonce leave Destiny's Child and become a solo singer?
# Answer: 2003
# --------------------------------------------------------------------------------
# Sample 4:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: In what city and state did Beyonce  grow up?
# Answer: Houston, Texas
# --------------------------------------------------------------------------------
# Sample 5:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: In which decade did Beyonce become famous?
# Answer: late 1990s
# --------------------------------------------------------------------------------
# Sample 6:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: In what R&B group was she the lead singer?
# Answer: Destiny's Child
# --------------------------------------------------------------------------------
# Sample 7:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: What album made her a worldwide known artist?
# Answer: Dangerously in Love
# --------------------------------------------------------------------------------
# Sample 8:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: Who managed the Destiny's Child group?
# Answer: Mathew Knowles
# --------------------------------------------------------------------------------
# Sample 9:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: When did Beyoncé rise to fame?
# Answer: late 1990s
# --------------------------------------------------------------------------------
# Sample 10:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: What role did Beyoncé have in Destiny's Child?
# Answer: lead singer
# --------------------------------------------------------------------------------
# Sample 11:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: What was the first album Beyoncé released as a solo artist?
# Answer: Dangerously in Love
# --------------------------------------------------------------------------------
# Sample 12:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: When did Beyoncé release Dangerously in Love?
# Answer: 2003
# --------------------------------------------------------------------------------
# Sample 13:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: How many Grammy awards did Beyoncé win for her first solo album?
# Answer: five
# --------------------------------------------------------------------------------
# Sample 14:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: What was Beyoncé's role in Destiny's Child?
# Answer: lead singer
# --------------------------------------------------------------------------------
# Sample 15:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
# Question: What was the name of Beyoncé's first solo album?
# Answer: Dangerously in Love
# --------------------------------------------------------------------------------
# Sample 16:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: After her second solo album, what other entertainment venture did Beyonce explore?
# Answer: acting
# --------------------------------------------------------------------------------
# Sample 17:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: Which artist did Beyonce marry?
# Answer: Jay Z
# --------------------------------------------------------------------------------
# Sample 18:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: To set the record for Grammys, how many did Beyonce win?
# Answer: six
# --------------------------------------------------------------------------------
# Sample 19:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: For what movie did Beyonce receive  her first Golden Globe nomination?
# Answer: Dreamgirls
# --------------------------------------------------------------------------------
# Sample 20:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: When did Beyonce take a hiatus in her career and take control of her management?
# Answer: 2010
# --------------------------------------------------------------------------------
# Sample 21:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: Which album was darker in tone from her previous work?
# Answer: Beyoncé
# --------------------------------------------------------------------------------
# Sample 22:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: After what movie portraying Etta James, did Beyonce create Sasha Fierce?
# Answer: Cadillac Records
# --------------------------------------------------------------------------------
# Sample 23:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: When did Destiny's Child end their group act?
# Answer: June 2005
# --------------------------------------------------------------------------------
# Sample 24:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: What was the name of Beyoncé's second solo album?
# Answer: B'Day
# --------------------------------------------------------------------------------
# Sample 25:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: What was Beyoncé's first acting job, in 2006?
# Answer: Dreamgirls
# --------------------------------------------------------------------------------
# Sample 26:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: Who is Beyoncé married to?
# Answer: Jay Z
# --------------------------------------------------------------------------------
# Sample 27:
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
# Question: What is the name of Beyoncé's alter-ego?
# Answer: Sasha Fierce
# --------------------------------------------------------------------------------
# Sample 28:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: In her music, what are some recurring elements in them?
# Answer: love, relationships, and monogamy
# --------------------------------------------------------------------------------
# Sample 29:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: Time magazine named her one of the most 100 what people of the century?
# Answer: influential
# --------------------------------------------------------------------------------
# Sample 30:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: Which magazine declared her the most dominant woman musician?
# Answer: Forbes
# --------------------------------------------------------------------------------
# Sample 31:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: In which decade did the Recording Industry Association of America recognize Beyonce as the The Top Certified Artist?
# Answer: 2000s
# --------------------------------------------------------------------------------
# Sample 32:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: What magazine rated Beyonce as the most powerful female musician in 2015?
# Answer: Forbes
# --------------------------------------------------------------------------------
# Sample 33:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: How did Beyonce describe herself as a feminist?
# Answer: modern-day feminist
# --------------------------------------------------------------------------------
# Sample 34:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: In which years did Time rate Beyonce in the 100 most influential people in the world?
# Answer: 2013 and 2014
# --------------------------------------------------------------------------------
# Sample 35:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: How many records has Beyonce sold in her 19 year career?
# Answer: 118 million
# --------------------------------------------------------------------------------
# Sample 36:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: How many records did Beyoncé sell as part of Destiny's Child?
# Answer: 60 million
# --------------------------------------------------------------------------------
# Sample 37:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: After leaving Destiny's Child, how many records did Beyoncé release under her own name?
# Answer: 118 million
# --------------------------------------------------------------------------------
# Sample 38:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: How many Grammy awards has Beyoncé won?
# Answer: 20
# --------------------------------------------------------------------------------
# Sample 39:
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
# Question: What magazine named Beyoncé as the most powerful female musician for 2015?
# Answer: Forbes
# --------------------------------------------------------------------------------
# Sample 40:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: Beyonce's younger sibling also sang with her in what band?
# Answer: Destiny's Child
# --------------------------------------------------------------------------------
# Sample 41:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: Where did Beyonce get her name from?
# Answer: her mother's maiden name
# --------------------------------------------------------------------------------
# Sample 42:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: What race was Beyonce's father?
# Answer: African-American
# --------------------------------------------------------------------------------
# Sample 43:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: Beyonce's childhood home believed in what religion?
# Answer: Methodist
# --------------------------------------------------------------------------------
# Sample 44:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: Beyonce's father worked as a sales manager for what company?
# Answer: Xerox
# --------------------------------------------------------------------------------
# Sample 45:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: Beyonce's mother worked in what industry?
# Answer: hairdresser and salon owner
# --------------------------------------------------------------------------------
# Sample 46:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: What younger sister of Beyonce also appeared in Destiny's Child?
# Answer: Solange
# --------------------------------------------------------------------------------
# Sample 47:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: Beyonce is a descendent of what Arcadian leader?
# Answer: Joseph Broussard
# --------------------------------------------------------------------------------
# Sample 48:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: What company did Beyoncé's father work for when she was a child?
# Answer: Xerox
# --------------------------------------------------------------------------------
# Sample 49:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: What did Beyoncé's mother own when Beyoncé was a child?
# Answer: salon
# --------------------------------------------------------------------------------
# Sample 50:
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
# Question: What is the name of Beyoncé's younger sister?
# Answer: Solange
# --------------------------------------------------------------------------------

# %% [markdown]
# # 3 - Preprocessing

# %%
for answer, text in zip(train_answers, train_texts):
    real_answer = answer['text']
    start_idx = answer['answer_start']
    # Get the real end index
    end_idx = start_idx + len(real_answer)

    # Deal with the problem of 1 or 2 more characters
    if text[start_idx:end_idx] == real_answer:
        answer['answer_end'] = end_idx
    # When the real answer is more by one character
    elif text[start_idx-1:end_idx-1] == real_answer:
        answer['answer_start'] = start_idx - 1
        answer['answer_end'] = end_idx - 1
    # When the real answer is more by two characters
    elif text[start_idx-2:end_idx-2] == real_answer:
        answer['answer_start'] = start_idx - 2
        answer['answer_end'] = end_idx - 2

# %%
for answer, text in zip(val_answers, val_texts):
    real_answer = answer['text']
    start_idx = answer['answer_start']
    # Get the real end index
    end_idx = start_idx + len(real_answer)

    # Deal with the problem of 1 or 2 more characters
    if text[start_idx:end_idx] == real_answer:
        answer['answer_end'] = end_idx
    # When the real answer is more by one character
    elif text[start_idx-1:end_idx-1] == real_answer:
        answer['answer_start'] = start_idx - 1
        answer['answer_end'] = end_idx - 1
    # When the real answer is more by two characters
    elif text[start_idx-2:end_idx-2] == real_answer:
        answer['answer_start'] = start_idx - 2
        answer['answer_end'] = end_idx - 2

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
train_encodings = tokenizer(train_texts, train_queries, truncation=True, padding=True)
val_encodings = tokenizer(val_texts, val_queries, truncation=True, padding=True)

# %%
def add_token_positions(encodings, answers):
    start_positions = []
    end_positions = []

    count = 0

    for i in range(len(answers)):
        start_positions.append(encodings.char_to_token(i, answers[i]['answer_start']))
        end_positions.append(encodings.char_to_token(i, answers[i]['answer_end']))

        # if start position is None, the answer passage has been truncated
        if start_positions[-1] is None:
            start_positions[-1] = tokenizer.model_max_length

        # if end position is None, the 'char_to_token' function points to the space after the correct token, so add - 1
        if end_positions[-1] is None:
            end_positions[-1] = encodings.char_to_token(i, answers[i]['answer_end'] - 1)

            # if end position is still None the answer passage has been truncated
            if end_positions[-1] is None:
                count += 1
                end_positions[-1] = tokenizer.model_max_length
    print(count)

    # Update the data in dictionary
    encodings.update({'start_positions': start_positions, 'end_positions': end_positions})

add_token_positions(train_encodings, train_answers)
add_token_positions(val_encodings, val_answers)
# Out:
# 0
# 0

# %%
class SquadDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

# %%
train_dataset = SquadDataset(train_encodings)
val_dataset = SquadDataset(val_encodings)

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=True)

# %% [markdown]
#  # Again 3- Preprocessing and cleaning the data

# %%
def predict(context, query):
    # Tokenize the inputs
    inputs = tokenizer.encode_plus(query, context, return_tensors='pt')

    # Ensure inputs are on the same device as the model
    device = next(model.parameters()).device
    inputs = {k: v.to(device) for k, v in inputs.items()}

    # Perform inference
    outputs = model(**inputs)
    answer_start = torch.argmax(outputs[0])  # Start position
    answer_end = torch.argmax(outputs[1]) + 1  # End position

    return tokenizer.decode(inputs['input_ids'][0][answer_start:answer_end])


def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re
    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()

    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)

    common_tokens = set(pred_tokens) & set(truth_tokens)

    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0

    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)
    return 2 * (prec * rec) / (prec + rec)

# %%
def give_an_answer(context,query,answer):
    prediction = predict(context,query)
    em_score = compute_exact_match(prediction, answer)
    f1_score = compute_f1(prediction, answer)
    print(f"Question: {query}")
    print(f"Prediction: {prediction}")
    print(f"True Answer: {answer}")
    print(f"EM: {em_score}")
    print(f"F1: {f1_score}")
    print("\n")

# %%
import re
import string

def normalize_text(s):
    """Lower text, remove punctuation and extra whitespace."""
    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)
    def white_space_fix(text):
        return ' '.join(text.split())
    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)
    def lower(text):
        return text.lower()
    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_exact_match(prediction, ground_truth):
    return int(normalize_text(prediction) == normalize_text(ground_truth))

def compute_f1(prediction, ground_truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(ground_truth).split()
    common = set(pred_tokens) & set(truth_tokens)
    if not common:
        return 0
    prec = len(common) / len(pred_tokens)
    rec = len(common) / len(truth_tokens)
    return 2 * (prec * rec) / (prec + rec)

# %% [markdown]
# # 4-Train the BERT QnA model. Evaluate the model.

# %%
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased').to(device)

# %%
from transformers import AdamW
optim = AdamW(model.parameters(), lr=5e-5)

epochs = 3

# %%
whole_train_eval_time = time.time()

train_losses = []
val_losses = []

print_every = 1000

for epoch in range(epochs):
    epoch_time = time.time()

    # Set model in train mode
    model.train()
    loss_of_epoch = 0

    print("Train")

    for batch_idx,batch in enumerate(train_loader):
        optim.zero_grad()

        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        start_positions = batch['start_positions'].to(device)
        end_positions = batch['end_positions'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask, start_positions=start_positions, end_positions=end_positions)
        loss = outputs[0]
        # do a backwards pass
        loss.backward()
        # update the weights
        optim.step()
        # Find the total loss
        loss_of_epoch += loss.item()

        if (batch_idx+1) % print_every == 0:
            print("Batch {:} / {:}".format(batch_idx+1,len(train_loader)),"\nLoss:", round(loss.item(),1),"\n")

    loss_of_epoch /= len(train_loader)
    train_losses.append(loss_of_epoch)

    ##########Evaluation##################

    # Set model in evaluation mode
    model.eval()

    print("Evaluate")

    loss_of_epoch = 0

    for batch_idx,batch in enumerate(val_loader):

        with torch.no_grad():

            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            start_positions = batch['start_positions'].to(device)
            end_positions = batch['end_positions'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask, start_positions=start_positions, end_positions=end_positions)
            loss = outputs[0]
            # Find the total loss
            loss_of_epoch += loss.item()

        if (batch_idx+1) % print_every == 0:
            print("Batch {:} / {:}".format(batch_idx+1,len(val_loader)),"\nLoss:", round(loss.item(),1),"\n")

    loss_of_epoch /= len(val_loader)
    val_losses.append(loss_of_epoch)

    # Print each epoch's time and train/val loss

    print("\n-------Epoch ", epoch+1,
          "-------"
          "\nTraining Loss:", train_losses[-1],
          "\nValidation Loss:", val_losses[-1],
          "\nTime: ",(time.time() - epoch_time),
          "\n-----------------------",
          "\n\n")

print("Total training and evaluation time: ", (time.time() - whole_train_eval_time))
# Out:
# Train
# Evaluate
#
# -------Epoch  1 -------
# Training Loss: 5.108685493469238
# Validation Loss: 5.023641109466553
# Time:  1.496729850769043
# -----------------------
#
#
# Train
# Evaluate
#
# -------Epoch  2 -------
# Training Loss: 3.909039088657924
# Validation Loss: 4.656170095716204
# Time:  1.5128142833709717
# -----------------------
#
#
# Train
# Evaluate
#
# -------Epoch  3 -------
# Training Loss: 3.2849630968911305
# Validation Loss: 4.489402089800153
# Time:  1.5217924118041992
# -----------------------
#
#
# Total training and evaluation time:  4.537001609802246

# %% [markdown]
# # 4. Train the BERT QnA model. Evaluate the model

# %%
# Load the fine-tuned model and tokenizer
from transformers import BertTokenizerFast, BertForQuestionAnswering
import torch

# Ensure model and tokenizer are loaded
tokenizer = BertTokenizerFast.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Prediction function
def predict(context, question):
    encoding = tokenizer.encode_plus(question, context, return_tensors='pt').to(device)
    outputs = model(**encoding)
    start_idx = torch.argmax(outputs.start_logits)
    end_idx = torch.argmax(outputs.end_logits) + 1
    answer = tokenizer.decode(encoding['input_ids'][0][start_idx:end_idx])
    return answer

# Evaluation metrics
def compute_exact_match(prediction, ground_truth):
    return int(prediction.strip().lower() == ground_truth.strip().lower())

def compute_f1(prediction, ground_truth):
    pred_tokens = prediction.strip().lower().split()
    truth_tokens = ground_truth.strip().lower().split()
    common_tokens = set(pred_tokens) & set(truth_tokens)
    if not common_tokens:
        return 0
    precision = len(common_tokens) / len(pred_tokens)
    recall = len(common_tokens) / len(truth_tokens)
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

# %% [markdown]
# # 5. Perform an Inference and show the predicted vs ground truth answers.

# %%
question_number = 1
total_f1 = 0
num_questions = 0

for sample in samples:
    print(f"\nContext: {sample['context'][:150]}...\n")  # Print a truncated context
    for q in sample['questions']:
        prediction = predict(sample["context"], q["question"])
        exact_match = compute_exact_match(prediction, q["answer"])
        f1_score = compute_f1(prediction, q["answer"])

        print(f"Question {question_number}: {q['question']}")
        print(f"Prediction: {prediction}")
        print(f"Ground Truth: {q['answer']}")
        print(f"Exact Match: {exact_match}")
        print(f"F1 Score: {f1_score}")
        print("-" * 50)

        total_f1 += f1_score
        num_questions += 1
        question_number += 1

average_f1 = total_f1 / num_questions if num_questions > 0 else 0
print(f"\nAverage F1 Score: {average_f1:.2f}")
# Out:
# Context: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Bor...
#
# Question 1: When did Beyonce start becoming popular?
# Prediction: late 1990s
# Ground Truth: in the late 1990s
# Exact Match: 0
# F1 Score: 0.6666666666666666
# --------------------------------------------------
# Question 2: What areas did Beyonce compete in when she was growing up?
# Prediction: singing and dancing
# Ground Truth: singing and dancing
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 3: When did Beyonce leave Destiny's Child and become a solo singer?
# Prediction: 2003
# Ground Truth: 2003
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 4: In what city and state did Beyonce  grow up?
# Prediction: houston
# Ground Truth: Houston, Texas
# Exact Match: 0
# F1 Score: 0
# --------------------------------------------------
# Question 5: In which decade did Beyonce become famous?
# Prediction: 1990s
# Ground Truth: late 1990s
# Exact Match: 0
# F1 Score: 0.6666666666666666
# --------------------------------------------------
# Question 6: In what R&B group was she the lead singer?
# Prediction: destiny ' s child
# Ground Truth: Destiny's Child
# Exact Match: 0
# F1 Score: 0.3333333333333333
# --------------------------------------------------
# Question 7: What album made her a worldwide known artist?
# Prediction: dangerously in love
# Ground Truth: Dangerously in Love
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 8: Who managed the Destiny's Child group?
# Prediction: mathew knowles
# Ground Truth: Mathew Knowles
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 9: When did Beyoncé rise to fame?
# Prediction: late 1990s
# Ground Truth: late 1990s
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 10: What role did Beyoncé have in Destiny's Child?
# Prediction: lead singer
# Ground Truth: lead singer
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 11: What was the first album Beyoncé released as a solo artist?
# Prediction: dangerously in love
# Ground Truth: Dangerously in Love
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 12: When did Beyoncé release Dangerously in Love?
# Prediction: 2003
# Ground Truth: 2003
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 13: How many Grammy awards did Beyoncé win for her first solo album?
# Prediction: five
# Ground Truth: five
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 14: What was Beyoncé's role in Destiny's Child?
# Prediction: lead singer
# Ground Truth: lead singer
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 15: What was the name of Beyoncé's first solo album?
# Prediction: dangerously in love
# Ground Truth: Dangerously in Love
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
#
# Context: Following the disbandment of Destiny's Child in June 2005, she released her second solo album, B'Day (2006), which contained hits "Déjà Vu", "Irreplac...
#
# Question 16: After her second solo album, what other entertainment venture did Beyonce explore?
# Prediction: acting
# Ground Truth: acting
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 17: Which artist did Beyonce marry?
# Prediction: jay z
# Ground Truth: Jay Z
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 18: To set the record for Grammys, how many did Beyonce win?
# Prediction: six
# Ground Truth: six
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 19: For what movie did Beyonce receive  her first Golden Globe nomination?
# Prediction: dreamgirls
# Ground Truth: Dreamgirls
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 20: When did Beyonce take a hiatus in her career and take control of her management?
# Prediction: 2010
# Ground Truth: 2010
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 21: Which album was darker in tone from her previous work?
# Prediction: beyonce
# Ground Truth: Beyoncé
# Exact Match: 0
# F1 Score: 0
# --------------------------------------------------
# Question 22: After what movie portraying Etta James, did Beyonce create Sasha Fierce?
# Prediction: cadillac records
# Ground Truth: Cadillac Records
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 23: When did Destiny's Child end their group act?
# Prediction: june 2005
# Ground Truth: June 2005
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 24: What was the name of Beyoncé's second solo album?
# Prediction: b ' day
# Ground Truth: B'Day
# Exact Match: 0
# F1 Score: 0
# --------------------------------------------------
# Question 25: What was Beyoncé's first acting job, in 2006?
# Prediction: dreamgirls
# Ground Truth: Dreamgirls
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 26: Who is Beyoncé married to?
# Prediction: jay z
# Ground Truth: Jay Z
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 27: What is the name of Beyoncé's alter-ego?
# Prediction:
# Ground Truth: Sasha Fierce
# Exact Match: 0
# F1 Score: 0
# --------------------------------------------------
#
# Context: A self-described "modern-day feminist", Beyoncé creates songs that are often characterized by themes of love, relationships, and monogamy, as well as ...
#
# Question 28: In her music, what are some recurring elements in them?
# Prediction: love, relationships, and monogamy
# Ground Truth: love, relationships, and monogamy
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 29: Time magazine named her one of the most 100 what people of the century?
# Prediction: influential
# Ground Truth: influential
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 30: Which magazine declared her the most dominant woman musician?
# Prediction: forbes
# Ground Truth: Forbes
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 31: In which decade did the Recording Industry Association of America recognize Beyonce as the The Top Certified Artist?
# Prediction: 2000s
# Ground Truth: 2000s
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 32: What magazine rated Beyonce as the most powerful female musician in 2015?
# Prediction: forbes
# Ground Truth: Forbes
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 33: How did Beyonce describe herself as a feminist?
# Prediction: modern - day
# Ground Truth: modern-day feminist
# Exact Match: 0
# F1 Score: 0
# --------------------------------------------------
# Question 34: In which years did Time rate Beyonce in the 100 most influential people in the world?
# Prediction: 2013 and 2014
# Ground Truth: 2013 and 2014
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 35: How many records has Beyonce sold in her 19 year career?
# Prediction: 118 million
# Ground Truth: 118 million
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 36: How many records did Beyoncé sell as part of Destiny's Child?
# Prediction: 60 million
# Ground Truth: 60 million
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 37: After leaving Destiny's Child, how many records did Beyoncé release under her own name?
# Prediction: 118 million
# Ground Truth: 118 million
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 38: How many Grammy awards has Beyoncé won?
# Prediction: 20
# Ground Truth: 20
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 39: What magazine named Beyoncé as the most powerful female musician for 2015?
# Prediction: forbes
# Ground Truth: Forbes
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
#
# Context: Beyoncé Giselle Knowles was born in Houston, Texas, to Celestine Ann "Tina" Knowles (née Beyincé), a hairdresser and salon owner, and Mathew Knowles, ...
#
# Question 40: Beyonce's younger sibling also sang with her in what band?
# Prediction: destiny ' s child
# Ground Truth: Destiny's Child
# Exact Match: 0
# F1 Score: 0.3333333333333333
# --------------------------------------------------
# Question 41: Where did Beyonce get her name from?
# Prediction: her mother ' s maiden name
# Ground Truth: her mother's maiden name
# Exact Match: 0
# F1 Score: 0.6
# --------------------------------------------------
# Question 42: What race was Beyonce's father?
# Prediction: african - american
# Ground Truth: African-American
# Exact Match: 0
# F1 Score: 0
# --------------------------------------------------
# Question 43: Beyonce's childhood home believed in what religion?
# Prediction: methodist
# Ground Truth: Methodist
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 44: Beyonce's father worked as a sales manager for what company?
# Prediction: xerox
# Ground Truth: Xerox
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 45: Beyonce's mother worked in what industry?
# Prediction: hairdresser and salon owner
# Ground Truth: hairdresser and salon owner
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 46: What younger sister of Beyonce also appeared in Destiny's Child?
# Prediction: solange
# Ground Truth: Solange
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 47: Beyonce is a descendent of what Arcadian leader?
# Prediction: joseph broussard
# Ground Truth: Joseph Broussard
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 48: What company did Beyoncé's father work for when she was a child?
# Prediction: xerox
# Ground Truth: Xerox
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 49: What did Beyoncé's mother own when Beyoncé was a child?
# Prediction: salon
# Ground Truth: salon
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
# Question 50: What is the name of Beyoncé's younger sister?
# Prediction: solange
# Ground Truth: Solange
# Exact Match: 1
# F1 Score: 1.0
# --------------------------------------------------
#
# Average F1 Score: 0.83

# %% [markdown]
# The accuracy is approx 83% , here better preprocessing steps and a larger dataset might increase the model accuracy or more like help in giving the right answer
